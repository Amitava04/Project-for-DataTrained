# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('UnitedStates_COVID_19_dataset.csv')
df
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
df['Country_Region'].unique()
# Out:
# array(['US'], dtype=object)

# %% [markdown]
# We can drop the Country_Region column as it contain only one type of data.

# %%
df.drop('Country_Region',inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Last_Update           58 non-null     object
#  2   Lat                   56 non-null     float64
#  3   Long_                 56 non-null     float64
#  4   Confirmed             58 non-null     int64
#  5   Deaths                58 non-null     int64
#  6   Recovered             42 non-null     float64
#  7   Active                58 non-null     float64
#  8   FIPS                  58 non-null     int64
#  9   Incident_Rate         56 non-null     float64
#  10  People_Tested         56 non-null     float64
#  11  People_Hospitalized   33 non-null     float64
#  12  Mortality_Rate        57 non-null     float64
#  13  UID                   58 non-null     int64
#  14  ISO3                  58 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
sns.heatmap(df.isnull(),cmap='gist_heat')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Null values can be seen through the heatmap.

# %%
df['Province_State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'Diamond Princess', 'District of Columbia', 'Florida', 'Georgia',
#        'Grand Princess', 'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Northern Mariana Islands', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Vermont', 'Virgin Islands', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df['ISO3'].unique()
# Out:
# array(['USA', 'ASM', 'GUM', 'MNP', 'PRI', 'VIR'], dtype=object)

# %%
df.dtypes
# Out:
# Province_State           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
df['Last_Update'].unique()
# Out:
# array(['2020-05-21 02:32:54'], dtype=object)

# %% [markdown]
# The time and date of all the data are same,hence we can drop it as it won't make any difference it the dataset.

# %%
df.drop('Last_Update',axis=1,inplace=True)

# %%
df
# Out:
#               Province_State      Lat     Long_  Confirmed  Deaths  Recovered  \
# 0                    Alabama  32.3182  -86.9023      13052     522        NaN
# 1                     Alaska  61.3707 -152.4044        401      10      352.0
# 2             American Samoa -14.2710 -170.1320          0       0        NaN
# 3                    Arizona  33.7298 -111.4312      14906     747     3773.0
# 4                   Arkansas  34.9697  -92.3731       5003     107     3852.0
# 5                 California  36.1162 -119.6816      85997    3497        NaN
# 6                   Colorado  39.0598 -105.3111      22797    1299     3478.0
# 7                Connecticut  41.5978  -72.7554      39017    3529     6264.0
# 8                   Delaware  39.3185  -75.5071       8194     310     3965.0
# 9           Diamond Princess      NaN       NaN         49       0        NaN
# 10      District of Columbia  38.8974  -77.0268       7551     407     1059.0
# ...

# %%
for col in ['Lat','Long_','Recovered','Incident_Rate','People_Tested','People_Hospitalized','Mortality_Rate','Testing_Rate','Hospitalization_Rate']:
    df[col].fillna(df[col].mean(),inplace=True)

# %%
sns.heatmap(df.isnull(),cmap='cool')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  58.000000   58.000000      58.000000     58.000000     58.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.694329   48.873770   52562.031122   4084.750891   9901.304545
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.872800  -99.697700    2596.000000     74.000000   1281.750000
# 50%    38.978600  -86.797300   10148.500000    385.000000   4987.000000
# 75%    42.214075  -77.072550   29395.500000   1394.250000   7007.428571
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      58.000000   5.800000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     395.554852   2.934948e+05
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
col=['Province_State','ISO3']
for i in col:
    df[i]=le.fit_transform(df[i])

# %%
df.corr()
# Out:
#                       Province_State       Lat     Long_  Confirmed    Deaths  \
# Province_State              1.000000  0.153948  0.089445   0.006490  0.015229
# Lat                         0.153948  1.000000 -0.278274   0.120391  0.119685
# Long_                       0.089445 -0.278274  1.000000   0.009951  0.028690
# Confirmed                   0.006490  0.120391  0.009951   1.000000  0.982191
# Deaths                      0.015229  0.119685  0.028690   0.982191  1.000000
# Recovered                   0.067595  0.030196 -0.041588   0.822547  0.830223
# Active                     -0.027612  0.119635  0.011604   0.985218  0.954378
# FIPS                       -0.195045 -0.000404  0.000396  -0.096696 -0.075053
# Incident_Rate              -0.078280  0.245693  0.041318   0.708436  0.710105
# People_Tested              -0.065428  0.084769 -0.077781   0.824136  0.739634
# People_Hospitalized         0.005461  0.026456  0.079677   0.869267  0.908279
# ...

# %%
plt.figure(figsize=(13,11))
sns.heatmap(df.corr(),cmap='cool',annot=True,fmt='0.0%')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is a strong corerelation between Deaths,Recovered,Active and Confirmed.

# %%
sns.distplot(df['Deaths'])
plt.show()

# %%
sns.distplot(df['Recovered'])
plt.show()

# %%
sns.distplot(df['Active'])
plt.show()

# %%
plt.figure(figsize=(20,20))
df['Deaths'].plot.bar()
plt.ylabel('No of Deaths')
plt.xticks(rotation=30)
plt.title('Deaths per day')
plt.show()

# %%
plt.figure(figsize=(20,20))
df['Active'].plot.bar()
plt.ylabel('No of Active Cases')
plt.xticks(rotation=30)
plt.title('Active cases per Day in Different provinces')
plt.show()

# %%
plt.figure(figsize=(20,20))
df['Confirmed'].plot.bar()
plt.ylabel('No of Confirmed')
plt.xticks(rotation=30)
plt.title('Confirmed cases in different provinces')
plt.show()

# %%
plt.figure(figsize=(20,20))
df['Recovered'].plot.bar()
plt.xticks(rotation=30)
plt.ylabel('No. of Recovered Patients')
plt.title('No of recovered patients in different provinces')
plt.show()

# %%
a=np.array(df['Deaths'])
b=np.array(df['Recovered'])

# %%
plt.xlabel('Death')
plt.ylabel('Recovered')
plt.scatter(a,b)
plt.show()

# %%
a=np.array(df['Deaths'])
b=np.array(df['Confirmed'])

# %%
plt.xlabel('Death')
plt.ylabel('Confirmed')
plt.scatter(a,b)
plt.show()

# %%
a=np.array(df['Deaths'])
b=np.array(df['Active'])

# %%
plt.xlabel('Death')
plt.ylabel('Active')
plt.scatter(a,b)
plt.show()

# %%
a=np.array(df['Confirmed'])
b=np.array(df['Active'])

# %%
plt.xlabel('Confirmed')
plt.ylabel('Active')
plt.scatter(a,b)
plt.show()

# %%
a=np.array(df['Confirmed'])
b=np.array(df['Recovered'])

# %%
plt.xlabel('Confirmed')
plt.ylabel('Recovered')
plt.scatter(a,b)
plt.show()

# %%
a=np.array(df['People_Hospitalized'])
b=np.array(df['Recovered'])

# %%
plt.xlabel('People_Hospitalized')
plt.ylabel('Recovered')
plt.scatter(a,b)
plt.show()

# %%
a=np.array(df['People_Hospitalized'])
b=np.array(df['Deaths'])

# %%
plt.xlabel('People_Hospitalized')
plt.ylabel('Deaths')
plt.scatter(a,b)
plt.show()

# %%
a=np.array(df['Incident_Rate'])
b=np.array(df['Mortality_Rate'])

# %%
plt.xlabel('Incident_Rate')
plt.ylabel('Mortality_Rate')
plt.scatter(a,b)
plt.show()

# %%
df.skew()
# Out:
# Province_State          0.000000
# Lat                    -2.250097
# Long_                   3.567919
# Confirmed               4.708614
# Deaths                  5.489201
# Recovered               3.647693
# Active                  4.180953
# FIPS                    5.269070
# Incident_Rate           1.988351
# People_Tested           2.829700
# People_Hospitalized     6.869437
# Mortality_Rate          0.496115
# UID                    -3.027480
# ISO3                   -4.126625
# Testing_Rate            1.313407
# Hospitalization_Rate    0.867341
# dtype: float64

# %% [markdown]
# Skewness can't be removed due to the loss of data.

# %%
df.plot(kind='box',subplots=True,layout=(5,5),figsize=(20,15))
# Out:
# Province_State             AxesSubplot(0.125,0.749828;0.133621x0.130172)
# Lat                     AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# Long_                    AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# Confirmed               AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# Deaths                  AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# Recovered                  AxesSubplot(0.125,0.593621;0.133621x0.130172)
# Active                  AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# FIPS                     AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# Incident_Rate           AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# People_Tested           AxesSubplot(0.766379,0.593621;0.133621x0.130172)
# People_Hospitalized        AxesSubplot(0.125,0.437414;0.133621x0.130172)
# Mortality_Rate          AxesSubplot(0.285345,0.437414;0.133621x0.130172)
# UID                      AxesSubplot(0.44569,0.437414;0.133621x0.130172)
# ...

# %% [markdown]
# Though Outliers are present but can't be removed due to the data gets effected by the removal of outlier.

# %%
x=df.drop('Recovered',axis=1)

# %%
y=df['Recovered']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=46)

# %%
model=[LinearRegression(),Lasso(),Ridge(),SVR(),DecisionTreeRegressor(),RandomForestRegressor(),KNeighborsRegressor()]

# %%
for m in model:
    m.fit(x_train,y_train)
    print('Score of',m,'is',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Mean Squared Error',mean_squared_error(y_test,predm))
    print('Mean Absolute error',mean_absolute_error(y_test,predm))
    print('R2 Score',r2_score(y_test,predm))
    print('**********************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression() is 0.9644753107706435
# Mean Squared Error 5022034.591188884
# Mean Absolute error 2036.351167630195
# R2 Score 0.9075517338767954
# **********************************************************************************
#
#
# Score of Lasso() is 0.9644741105349062
# Mean Squared Error 5012938.976501717
# Mean Absolute error 2034.4764782377035
# R2 Score 0.9077191707575825
# **********************************************************************************
#
#
# Score of Ridge() is 0.9644449301562182
# Mean Squared Error 5061665.550052469
# Mean Absolute error 2036.0838969712706
# R2 Score 0.9068221862472019
# **********************************************************************************
#
#
# Score of SVR() is -0.0033906721373651028
# Mean Squared Error 54585701.36926348
# Mean Absolute error 5070.058797134331
# R2 Score -0.004842430906633943
# **********************************************************************************
#
#
# ...

# %% [markdown]
# Observation:
#
# Linear Regression is the best model with r2 score .90

# %%
model=[LinearRegression(),Lasso(),Ridge(),SVR(),DecisionTreeRegressor(),RandomForestRegressor(),KNeighborsRegressor()]

# %%
for c in model:
    score=cross_val_score(c,x,y,scoring='r2',cv=6)
    print('Model',c)
    print('Score',score)
    print('Standard Deviation',score.std())
    print('Mean',score.mean())
    print('************************************************************')
    print('\n')
# Out:
# Model LinearRegression()
# Score [-5.31317463  0.27262285  0.87548661  0.80611031  0.32585619  0.8765399 ]
# Standard Deviation 2.2293429007584638
# Mean -0.3594264610849433
# ************************************************************
#
#
# Model Lasso()
# Score [-5.27479922  0.25844487  0.87448516  0.8051128   0.3291192   0.87777312]
# Standard Deviation 2.2145723110124704
# Mean -0.3549773459573344
# ************************************************************
#
#
# Model Ridge()
# Score [-3.52460972  0.29024758  0.87388344  0.7900603   0.32939058  0.88347741]
# Standard Deviation 1.5685826055745835
# Mean -0.05959173371042531
# ************************************************************
#
#
# Model SVR()
# Score [-2.97443984e-04 -4.38861532e-03 -2.91867952e-01 -7.71498143e-02
#  -6.51610748e-02  1.18298135e-07]
# Standard Deviation 0.10271637868013032
# Mean -0.07314413042711349
# ************************************************************
#
#
# Model DecisionTreeRegressor()
# ...

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
plt.scatter(y_test,predlr)
plt.xlabel('y_test')
plt.ylabel('Predicted Y')
plt.title('Scatter plot between data and predicted data')
plt.show()

# %%
import pickle

# %%
filename='US_Covid_19.pkl'
pickle.dump(lr,open(filename,'wb'))
